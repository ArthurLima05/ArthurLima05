# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurLima05/ArthurLima05/blob/main/Redu%C3%A7%C3%A3oDimensionalidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

image_path ='/content/drive/MyDrive/Lenna(test_image).png'
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt

color_img = cv2.imread(image_path)

# %%
if color_img is None:
  print("Erro em carregar a imagem")

else:
  gray_image = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)

# %%
threshold = 128
_, binary_image = cv2.threshold(gray_image, threshold, 255, cv2.THRESH_BINARY)

# %%
plt.figure(figsize=(15, 5))

# Primeira Imagem
plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(color_img, cv2.COLOR_BGR2RGB))
plt.title('Imagem Colorida')
plt.axis('off')

# Segunda Imagem
plt.subplot(1, 3, 2)
plt.imshow(gray_image, cmap='gray')
plt.title('Imagem em Escala de Cinza')
plt.axis('off')

# Terceira Imagem
plt.subplot(1, 3, 3)
plt.imshow(binary_image, cmap='gray')
plt.title('Imagem Binária')
plt.axis('off')

plt.tight_layout()
plt.show()
